# %% [markdown]
# # SVM - Model

# %%
# import libraries
import matplotlib.pyplot as plt
from IPython.display import Image
from collections import Counter
from sklearn.svm import SVC
import PIL as pil
import os as os
import numpy as np
import pandas as pd
import cv2
import seaborn as sns

# %matplotlib inline

# %%
n_classes = 256
image_count = 30607
image_height = 382
image_width = 345
image_pixels = image_height * image_width * 3
image_pixels
# Out:
# 395370

# %%
def prepare_training_data(path, n_classes):
    images = np.empty((0, image_pixels), dtype=np.int8)
    targets = np.empty(0, dtype=np.int8)
    label = 1

    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for image in os.listdir(folder_path):
                if image.endswith('.jpg'):
                    try:
                        image_path = os.path.join(folder_path, image)
                        im = pil.Image.open(image_path)
                        im = np.array(im)
                        im = im.reshape(-1)
                        print(im.shape)
                        images = np.append(images, [im], axis=0)
                        targets = np.append(targets, label)
                    except:
                        continue
            label += 1
    return images, targets

# %%
images, labels = prepare_training_data('data_resized/', 256)
# Out:
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (131790,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)
# (395370,)

# %%
im = pil.Image.open('data_resized/001.ak47/001_0001.jpg')
im = np.array(im)
im = im.reshape(-1)
im2 = pil.Image.open('data_resized/003.backpack/003_0004.jpg')
im2 = np.array(im2)
im2 = im.reshape(-1)

# %%
#images = np.zeros(shape=(image_count, image_pixels), dtype=np.int8)
images = np.empty((0, image_pixels), dtype=np.int8)

# %%
images
# Out:
# array([], shape=(0, 395370), dtype=int8)

# %%
images = np.append(images, [im], axis=0)

# %%
images = np.append(images, [im2], axis=0)

# %%
images
# Out:
# array([[ 94, 104, 113, ..., 121, 125, 128],
#        [ 94, 104, 113, ..., 121, 125, 128]], dtype=int16)

# %%
images.shape
# Out:
# (2, 395370)

# %%
targets = np.empty(0, dtype=np.int8)

# %%
targets
# Out:
# array([], dtype=int8)

# %%
targets = np.append(targets, [2])

# %%
np.append(targets, [1234])
# Out:
# array([   2, 1234])
